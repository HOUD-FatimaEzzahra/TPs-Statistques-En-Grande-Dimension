# %%
import pandas as ps
iris=ps.read_csv('iris.csv')

# %%
[n,p]=iris.shape
iris.shape[0]
iris.shape[1]
# Out:
# 5

# %%
iris.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
iris.tail()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica

# %%
data={"Individus":["élève1","élève2","élève3","élève4","élève5"],"Math":[12,19,2,9,14],"Arabe":[17,10,16,18,11],"PC":[10,16,6,13,16],"Français":[8,12,13,16,14]}
df=ps.DataFrame(data)
print(df)
# Out:
#   Individus  Math  Arabe  PC  Français
# 0    élève1    12     17  10         8
# 1    élève2    19     10  16        12
# 2    élève3     2     16   6        13
# 3    élève4     9     18  13        16
# 4    élève5    14     11  16        14

# %%
import matplotlib.pyplot as plt

# %%
img=plt.imread("panda.jpg")
print(img.shape)
plt.imshow(img)
plt.axis("off");
# Out:
# (600, 600, 3)

# %%
import numpy as np

# %%
data=np.random.randn(100,5)
print(data)
# Out:
# [[-1.12157017e+00  3.96531574e-01 -9.70098846e-02  3.91226644e-01
#   -8.34170912e-01]
#  [-4.76732231e-01 -1.68410966e-01  9.44665776e-01  1.50754292e-01
#   -1.11715480e+00]
#  [-1.71011332e+00 -1.92752407e-01 -1.45624739e+00 -1.37482165e-01
#    1.76691048e-01]
#  [ 1.44021290e+00  7.07783462e-01 -1.37023604e+00 -2.16196415e+00
#    2.44136460e+00]
#  [-7.97897132e-01  1.08350905e+00 -2.66967048e-01  5.99108913e-01
#   -4.91430404e-01]
#  [-6.26528020e-01  6.76847166e-01 -8.76619652e-01  9.47525358e-02
#    3.99984350e-02]
#  [-1.85391834e+00  1.17883846e+00 -9.66243949e-01  3.81017048e-01
#    1.53316878e+00]
#  [ 6.24201532e-01 -4.83679246e-01  4.69379868e-01 -5.83817768e-01
#   -6.16140436e-01]
#  [-4.54004391e-01 -3.58026925e-01 -1.18453949e+00  8.84075506e-01
#    8.73955377e-01]
#  [ 1.59887570e+00 -1.86531264e-01 -5.16373182e-01  7.01438106e-01
#    1.93639192e-01]
#  [-6.21881554e-01  2.38519307e+00 -1.95793734e+00 -1.30149386e-02
#    1.03730522e+00]
# ...

# %%
data2=np.random.randn(20,3)
print(data2)
# Out:
# [[ 0.24664644 -1.66913546  0.24247452]
#  [-1.60292342  0.22806819 -0.45575962]
#  [-0.36172754 -0.28055502  2.41916074]
#  [-0.14524261 -0.34116302  0.20484911]
#  [ 0.82674897  0.65039719  0.7917953 ]
#  [ 0.9328843   0.81807226 -1.76849772]
#  [-0.72204859 -1.44128439 -1.9701241 ]
#  [-0.52887721  1.32565414 -1.51266352]
#  [ 0.58671011 -0.81725703  0.69128638]
#  [-0.29393699  1.11606747  0.59907416]
#  [ 0.25096944 -0.46239061 -0.29186643]
#  [ 0.42902219 -0.94803003  0.06194462]
#  [-1.75360371  0.0871434  -0.14243291]
#  [-0.61846102 -0.54176167 -0.07617493]
#  [-1.71423925 -1.18310805 -0.44468284]
#  [-0.64908424 -0.12581852  1.18273463]
#  [-0.91885149 -0.74391733  0.12854799]
#  [ 0.18939744 -0.93723098  1.62100233]
#  [ 1.00378785 -0.55484036  0.44885471]
#  [-0.3550939  -0.15525572 -0.62629672]]
